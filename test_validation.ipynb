# %%
import bcolz
import numpy as np

carray=bcolz.carray(rootdir=r"D:\OneDrive\OneDrive - The Hong Kong Polytechnic University\Datasets\validation_lfw\lfw",mode="r")

# %%
carray.shape
# Out:
# (12000, 3, 112, 112)

# %%
carray[0]
# Out:
# array([[[ 0.92941177,  0.94509804,  0.96862745, ..., -0.81960785,
#          -0.7490196 , -0.73333335],
#         [ 0.9137255 ,  0.92941177,  0.94509804, ..., -0.8901961 ,
#          -0.88235295, -0.8666667 ],
#         [ 0.92156863,  0.92941177,  0.9372549 , ..., -0.8745098 ,
#          -0.8980392 , -0.88235295],
#         ...,
#         [-0.79607844, -0.79607844, -0.79607844, ...,  0.37254906,
#           0.43529415,  0.4901961 ],
#         [-0.79607844, -0.79607844, -0.8039216 , ...,  0.39607847,
#           0.48235297,  0.5372549 ],
#         [-0.79607844, -0.79607844, -0.79607844, ...,  0.45098042,
#           0.5294118 ,  0.6156863 ]],
#
#        [[ 0.9137255 ,  0.92941177,  0.9529412 , ..., -0.827451  ,
#          -0.7490196 , -0.70980394],
#         [ 0.8980392 ,  0.9137255 ,  0.92941177, ..., -0.8980392 ,
#          -0.8666667 , -0.84313726],
#         [ 0.90588236,  0.9137255 ,  0.92156863, ..., -0.88235295,
#          -0.8901961 , -0.8666667 ],
#         ...,
# ...

# %%
import numpy as np
import cv2
data=np.transpose(carray[2],(1,2,0))
data=cv2.cvtColor(data, cv2.COLOR_BGR2RGB)
from matplotlib import pyplot as plt
plt.imshow(data, interpolation='nearest')
plt.show()

from PIL import Image

img = Image.fromarray(data.astype(np.uint8))
img.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
data.shape
# Out:
# (112, 112, 3)

# %%
a=np.load(r"D:\OneDrive\OneDrive - The Hong Kong Polytechnic University\Datasets\validation_lfw\lfw_list.npy")

# %%
a.shape
# Out:
# array([ True,  True,  True, ..., False, False, False])
